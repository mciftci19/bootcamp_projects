# %%
import pandas as pd
df = pd.read_csv('/content/Superstore Data (Python Assessment).csv')
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation              D  84835.0        0
# 1         1        1961  Graduation              S  57091.0        0
# 2     10476        1958  Graduation              M  67267.0        0
# 3      1386        1967  Graduation              T  32474.0        1
# 4      5371        1989  Graduation              S  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2233  10142        1976         PhD              D  66476.0        0
# 2234   5263        1977    2n Cycle              M  31056.0        1
# 2235     22        1976  Graduation              D  46310.0        1
# 2236    528        1978  Graduation              M  65819.0        0
# 2237   4070        1969         PhD              M  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# 1            0   6/15/2014        0       464  ...                7
# 2            1   5/13/2014        0       134  ...               15
# 3            1   11/5/2014        0        10  ...                0
# 4            0    8/4/2014        0         6  ...               11
# ...        ...         ...      ...       ...  ...              ...
# 2233         1    7/3/2013       99       372  ...               47
# 2234         0   1/22/2013       99         5  ...                3
# 2235         0   3/12/2012       99       185  ...               15
# 2236         0  11/29/2012       99       267  ...              149
# 2237         2    1/9/2012       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# 0                  189           218                  1                4
# 1                    0            37                  1                7
# 2                    2            30                  1                3
# 3                    0             0                  1                1
# 4                    0            34                  2                3
# ...                ...           ...                ...              ...
# 2233                48            78                  2                5
# 2234                 8            16                  1                1
# 2235                 5            14                  2                6
# 2236               165            63                  1                5
# 2237                 0           144                  1                8
#
#       NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  Response  \
# 0                       4                  6                  1         1
# 1                       3                  7                  5         1
# 2                       2                  5                  2         0
# 3                       0                  2                  7         0
# 4                       1                  2                  7         1
# ...                   ...                ...                ...       ...
# 2233                    2                 11                  4         0
# 2234                    0                  3                  8         0
# 2235                    1                  5                  8         0
# 2236                    4                 10                  3         0
# 2237                    5                  4                  7         1
#
#       Complain
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 2233         0
# 2234         0
# 2235         0
# 2236         0
# 2237         0
#
# [2238 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2238 entries, 0 to 2237
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2238 non-null   int64
#  1   Year_Birth           2238 non-null   int64
#  2   Education            2238 non-null   object
#  3   Marital_Status       2238 non-null   object
#  4   Income               2214 non-null   float64
#  5   Kidhome              2238 non-null   int64
#  6   Teenhome             2238 non-null   int64
#  7   Dt_Customer          2238 non-null   object
#  8   Recency              2238 non-null   int64
#  9   MntWines             2238 non-null   int64
#  10  MntFruits            2238 non-null   int64
#  11  MntMeatProducts      2238 non-null   int64
#  12  MntFishProducts      2238 non-null   int64
#  13  MntSweetProducts     2238 non-null   int64
#  14  MntGoldProds         2238 non-null   int64
#  15  NumDealsPurchases    2238 non-null   int64
#  16  NumWebPurchases      2238 non-null   int64
#  17  NumCatalogPurchases  2238 non-null   int64
#  18  NumStorePurchases    2238 non-null   int64
#  19  NumWebVisitsMonth    2238 non-null   int64
#  20  Response             2238 non-null   int64
#  21  Complain             2238 non-null   int64
# dtypes: float64(1), int64(18), object(3)
# memory usage: 384.8+ KB

# %%
#Descriptive statistics
df.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2238.000000  2238.000000    2214.000000  2238.000000  2238.000000
# mean    5591.962913  1968.802055   52250.697832     0.444593     0.505809
# std     3244.208285    11.988769   25184.187770     0.538475     0.544581
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2829.500000  1959.000000   35265.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51400.500000     0.000000     0.000000
# 75%     8425.250000  1977.000000   68592.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2238.000000  2238.000000  2238.000000      2238.000000
# mean     49.150581   303.919571    26.323056       167.054513
# std      28.942548   336.747394    39.785104       225.789149
# min       0.000000     0.000000     0.000000         0.000000
# 25%      24.000000    23.250000     1.000000        16.000000
# 50%      49.000000   173.000000     8.000000        67.000000
# 75%      74.000000   504.750000    33.000000       232.000000
# max      99.000000  1493.000000   199.000000      1725.000000
#
#        MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# count      2238.000000       2238.000000   2238.000000        2238.000000
# mean         37.555407         27.084450     44.023682           2.322609
# std          54.644192         41.292674     52.190719           1.931444
# min           0.000000          0.000000      0.000000           0.000000
# 25%           3.000000          1.000000      9.000000           1.000000
# 50%          12.000000          8.000000     24.000000           2.000000
# 75%          50.000000         33.000000     56.000000           3.000000
# max         259.000000        263.000000    362.000000          15.000000
#
#        NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# count      2238.000000          2238.000000        2238.000000
# mean          4.082216             2.663539           5.789991
# std           2.778588             2.923984           3.252405
# min           0.000000             0.000000           0.000000
# 25%           2.000000             0.000000           3.000000
# 50%           4.000000             2.000000           5.000000
# 75%           6.000000             4.000000           8.000000
# max          27.000000            28.000000          13.000000
#
#        NumWebVisitsMonth     Response     Complain
# count        2238.000000  2238.000000  2238.000000
# mean            5.314120     0.148794     0.009383
# std             2.426402     0.355964     0.096434
# min             0.000000     0.000000     0.000000
# 25%             3.000000     0.000000     0.000000
# 50%             6.000000     0.000000     0.000000
# 75%             7.000000     0.000000     0.000000
# max            20.000000     1.000000     1.000000

# %%
# Box Plot for Income
import matplotlib

df['Income'].plot(kind='box')
# Out:
# <Axes: >

# %%
# Replacing the Missing Income Values with the Mean Income

df['Income'] = df['Income'].fillna(df['Income'].mean())

# %%
# Calculation of Total Amount Spent on Products
df['TotalMntSpent'] = df['MntWines'] + df['MntFruits'] + df['MntMeatProducts'] + df['MntFishProducts'] + df['MntSweetProducts'] + df['MntGoldProds']

# %%
# Pie Chart for Total Amount Spent on Products

import matplotlib.pyplot as plt
# Check if the required columns exist
if all(col in df.columns for col in ['MntWines', 'MntFruits', 'MntMeatProducts',
                                     'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']):
    # Calculate the total sum for each product category across all rows
    category_totals = {
        'Wines': df['MntWines'].sum(),
        'Fruits': df['MntFruits'].sum(),
        'Meat Products': df['MntMeatProducts'].sum(),
        'Fish Products': df['MntFishProducts'].sum(),
        'Sweet Products': df['MntSweetProducts'].sum(),
        'Gold Products': df['MntGoldProds'].sum(),
    }

    # Create a pie chart
    plt.figure(figsize=(8, 8))
    plt.pie(
        category_totals.values(),
        labels=category_totals.keys(),
        autopct='%1.1f%%',
        startangle=140,
        colors=plt.cm.Paired.colors
    )

    # Add title
    plt.title('Proportions of Product Categories in TotalMntSpent', fontsize=14)

    # Show the chart
    plt.show()

else:
    print("One or more required columns are missing from the dataset.")

# %%
# Distribution of Total Amount Spent

import matplotlib.pyplot as plt
import seaborn as sns

# Create the histogram and KDE plot
plt.figure(figsize=(10, 6))
sns.histplot(df['TotalMntSpent'], kde=True, color='blue', bins=30)

# Customize the plot
plt.title('Distribution of Total Amount Spent', fontsize=14)
plt.xlabel('Total Amount Spent', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Calculation of Total Number of Purchases
df['TotalNumPurchases'] = df['NumWebPurchases'] + df['NumCatalogPurchases'] + df['NumStorePurchases'] + df['NumDealsPurchases']

# %%
# Pie Chart for Total Number of Purchases

import matplotlib.pyplot as plt
# Check if the required columns exist
if all(col in df.columns for col in ['NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumDealsPurchases']):
    # Calculate the total number of purchases for each category across all rows
    purchase_totals = {
        'Web Purchases': df['NumWebPurchases'].sum(),
        'Catalog Purchases': df['NumCatalogPurchases'].sum(),
        'Store Purchases': df['NumStorePurchases'].sum(),
        'Deals Purchases': df['NumDealsPurchases'].sum(),
    }

    # Create a pie chart
    plt.figure(figsize=(8, 8))
    plt.pie(
        purchase_totals.values(),
        labels=purchase_totals.keys(),
        autopct='%1.1f%%',
        startangle=140,
        colors=plt.cm.Paired.colors
    )

    # Add title
    plt.title('Proportions of Purchase Types in TotalNumPurchases', fontsize=14)

    # Show the chart
    plt.show()

else:
    print("One or more required columns are missing from the dataset.")

# %%
# Distribtuion of Total Number of Purchases

import matplotlib.pyplot as plt
import seaborn as sns

# Check if the column exists
if 'TotalNumPurchases' in df.columns:
    # Histogram
    plt.figure(figsize=(10, 6))
    sns.histplot(df['TotalNumPurchases'], bins=15, kde=True, color='blue', alpha=0.7)
    plt.title('Distribution of TotalNumPurchases', fontsize=14)
    plt.xlabel('Total Number of Purchases', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.grid(alpha=0.4)
    plt.show()



else:
    print("The column 'TotalNumPurchases' is not in the dataset.")

# %%
#Frequency of Education Levels
df['Education'].value_counts()
# Out:
# Education
# Graduation    1127
# PhD            484
# Master         370
# 2n Cycle       203
# Basic           54
# Name: count, dtype: int64

# %%
#Proportion of Education Levels

import matplotlib.pyplot as plt
# Check if 'Education' column exists
if 'Education' in df.columns:
    # Count the occurrences of each education level
    education_counts = df['Education'].value_counts()

# Create a pie chart
    plt.figure(figsize=(8, 8))
    plt.pie(
        education_counts,
        labels=education_counts.index,
        autopct='%1.1f%%',
        startangle=140,
        colors=plt.cm.Paired.colors
    )

    # Add a title
    plt.title('Proportion of Education Levels', fontsize=14)

# %%
#Frequency of Marital Status
df['Marital_Status'].value_counts()
# Out:
# Marital_Status
# M        864
# T        580
# S        480
# D        232
# W         77
# Other      5
# Name: count, dtype: int64

# %%
#Pie Chart for Proportion of Marital Status

import matplotlib.pyplot as plt
# Check if 'Marital_Status' column exists
if 'Marital_Status' in df.columns:
    # Count the occurrences of each education level
    education_counts = df['Marital_Status'].value_counts()

# Create a pie chart
    plt.figure(figsize=(8, 8))
    plt.pie(
        education_counts,
        labels=education_counts.index,
        autopct='%1.1f%%',
        startangle=140,
        colors=plt.cm.Paired.colors
    )

    # Add a title
    plt.title('Proportion of Marital_Status Levels', fontsize=14)

# %%
# Calculation of Total Children Living in the Household
df["Children"] = df["Kidhome"] +  df["Teenhome"]

# %%
# Distribution of Children Living in the Household
df['Children'].value_counts()
# Out:
# Children
# 1    1126
# 0     638
# 2     421
# 3      53
# Name: count, dtype: int64

# %%
# Pie Chart for Distribution of Children

import matplotlib.pyplot as plt
# Check if the 'Children' column exists
if 'Children' in df.columns:
    # Count the occurrences of each value in the 'Children' column
    children_counts = df['Children'].value_counts()

    # Create a pie chart
    plt.figure(figsize=(8, 8))
    plt.pie(
        children_counts,
        labels=children_counts.index,
        autopct='%1.1f%%',
        startangle=140,
        colors=plt.cm.Paired.colors
    )

    # Add a title
    plt.title('Proportion of Families by Number of Children', fontsize=14)

    # Show the plot
    plt.show()

# %%
# Distribution of Recency

import matplotlib.pyplot as plt
import seaborn as sns

# Binning Recency into 10-day intervals
df['Recency_Binned'] = pd.cut(df['Recency'], bins=range(0, df['Recency'].max() + 10, 10), right=False)

# Create the bar plot
plt.figure(figsize=(10, 6))
sns.countplot(x='Recency_Binned', data=df, palette='Set2')

# Customize the plot
plt.title('Distribution of Recency', fontsize=14)
plt.xlabel('Recency (Days Since Last Purchase)', fontsize=12)
plt.ylabel('Count of Customers', fontsize=12)
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# <ipython-input-44-306cbac46128>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Recency_Binned', data=df, palette='Set2')

# %%
# Frequency of Total Number of Complaints
df['Complain'].value_counts()
# Out:
# Complain
# 0    2217
# 1      21
# Name: count, dtype: int64

# %%
# Visualisation of Complaints

import matplotlib.pyplot as plt

# Assuming 'Complaints' is the column in your DataFrame representing the complaints data
# Calculate the counts of each category in the 'Complaints' column
complaints_counts = df['Complain'].value_counts()

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(complaints_counts, labels=complaints_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#99ff99'])

# Customize the chart
plt.title('Distribution of Complaints', fontsize=14)
plt.axis('equal')  # Equal aspect ratio ensures that the pie is drawn as a circle
plt.show()

# %%
# Pie-chart for Response

import matplotlib.pyplot as plt

response_counts = df['Response'].value_counts()

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(response_counts, labels=response_counts.index, autopct='%1.1f%%', startangle=90, colors=['#ff9999', '#66b3ff'])

# Customize the plot
plt.title('Distribution of Campaign Responses', fontsize=14)
plt.axis('equal')  # Ensure the pie chart is a circle
plt.show()

# %%
# The Relationship between Total Amount Spent and Marital Status

import matplotlib.pyplot as plt
if 'Marital_Status' in df.columns and 'TotalMntSpent' in df.columns:
    # Group by Marital_Status and calculate the mean of TotalMntSpent
    marital_spending = df.groupby('Marital_Status')['TotalMntSpent'].mean().sort_values()

    # Bar plot for average spending
    plt.figure(figsize=(8, 5))
    marital_spending.plot(kind='bar', color='skyblue', edgecolor='black')
    plt.title('Average Total Amount Spent by Marital Status', fontsize=14)
    plt.xlabel('Marital Status', fontsize=12)
    plt.ylabel('Average TotalMntSpent', fontsize=12)
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
# The Relationship between Total Amount Spent and the Number of Children

import matplotlib.pyplot as plt
if 'Children' in df.columns and 'TotalMntSpent' in df.columns:
    # Bar Plot: Average spending per number of children
    avg_spending = df.groupby('Children')['TotalMntSpent'].mean().sort_index()

    plt.figure(figsize=(8, 5))
    avg_spending.plot(kind='bar', color='lightblue', edgecolor='black')
    plt.title('Average Total Amount Spent by Number of Children', fontsize=14)
    plt.xlabel('Number of Children', fontsize=12)
    plt.ylabel('Average TotalMntSpent', fontsize=12)
    plt.xticks(rotation=0)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
# The Relationship between Recency and Total Amount Spent
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot with a regression line
plt.figure(figsize=(10, 6))
sns.regplot(x='Recency', y='TotalMntSpent', data=df, scatter_kws={'alpha':0.6}, line_kws={'color': 'red', 'linewidth': 2})

# Customize the plot
plt.title('Relationship Between Total Amount Spent and Recency', fontsize=14)
plt.xlabel('Recency (Days Since Last Purchase)', fontsize=12)
plt.ylabel('Total Amount Spent', fontsize=12)
plt.grid(True, alpha=0.3)
plt.show()

# %%
# The Relationship between Income and Total Amount Spent

import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# Check if the required columns exist
if 'Income' in df.columns and 'TotalMntSpent' in df.columns:
    # Drop rows with missing values in 'Income' or 'TotalMntSpent'
    df = df.dropna(subset=['Income', 'TotalMntSpent'])

    # Define the dependent (Y) and independent (X) variables
    X = df['Income']
    y = df['TotalMntSpent']

    # Add a constant to the independent variable (for intercept in statsmodels)
    X = sm.add_constant(X)

    # Fit the regression model
    model = sm.OLS(y, X).fit()

    # Print the summary of the regression
    print(model.summary())

    # Scatter plot with regression line
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=df['Income'], y=df['TotalMntSpent'], color='blue', alpha=0.7)
    plt.plot(df['Income'], model.predict(X), color='red', label='Regression Line')
    plt.title('Regression of Income on Total Amount Spent', fontsize=14)
    plt.xlabel('Income', fontsize=12)
    plt.ylabel('TotalMntSpent', fontsize=12)
    plt.legend()
    plt.grid(alpha=0.5)
    plt.show()

else:
    print("The required columns 'Income' and 'TotalMntSpent' are not in the dataset.")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          TotalMntSpent   R-squared:                       0.442
# Model:                            OLS   Adj. R-squared:                  0.442
# Method:                 Least Squares   F-statistic:                     1770.
# Date:                Sat, 14 Dec 2024   Prob (F-statistic):          1.97e-285
# Time:                        11:57:24   Log-Likelihood:                -16848.
# No. Observations:                2238   AIC:                         3.370e+04
# Df Residuals:                    2236   BIC:                         3.371e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -229.4195     22.020    -10.419      0.000    -272.601    -186.238
# Income         0.0160      0.000     42.070      0.000       0.015       0.017
# ==============================================================================
# Omnibus:                     2543.262   Durbin-Watson:                   1.795
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1490125.446
# Skew:                          -5.048   Prob(JB):                         0.00
# Kurtosis:                     129.008   Cond. No.                     1.34e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# The Relationship between Complaint and Total Amount Spent
# Calculate mean spending for customers with and without complaints
mean_spending_by_complaint = df.groupby('Complain')['TotalMntSpent'].mean()

# Create a bar plot
plt.figure(figsize=(8, 6))
mean_spending_by_complaint.plot(kind='bar', color=['#66b3ff', '#ff9999'], alpha=0.8, edgecolor='black')

# Customize the plot
plt.title('Mean Total Amount Spent by Complaint Status', fontsize=14)
plt.xlabel('Complaint Status (0 = No, 1 = Yes)', fontsize=12)
plt.ylabel('Average Total Amount Spent', fontsize=12)
plt.xticks([0, 1], labels=['No Complaint', 'Complaint'], rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# The Relationship between Response and Total amount Spent

# Calculate mean spending for each response group
mean_spending = df.groupby('Response')['TotalMntSpent'].mean()

# Create a bar plot
plt.figure(figsize=(8, 6))
mean_spending.plot(kind='bar', color=['#66b3ff', '#ff9999'], alpha=0.8, edgecolor='black')

# Customize the plot
plt.title('Mean Total Amount Spent by Response', fontsize=14)
plt.xlabel('Response (Yes/No)', fontsize=12)
plt.ylabel('Average Total Amount Spent', fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Visualizing the Relationship Between TotalNumPurchases and Marital_Status
import matplotlib.pyplot as plt
import seaborn as sns

# Check if the columns exist
if all(col in df.columns for col in ['TotalNumPurchases', 'Marital_Status']):

    # Violin Plot
    plt.figure(figsize=(10, 6))
    sns.violinplot(x='Marital_Status', y='TotalNumPurchases', data=df, palette='Set1')
    plt.title('Violin Plot of TotalNumPurchases by Marital Status', fontsize=14)
    plt.xlabel('Marital Status', fontsize=12)
    plt.ylabel('Total Number of Purchases', fontsize=12)
    plt.xticks(rotation=45)
    plt.grid(alpha=0.4)
    plt.show()

else:
    print("One or more required columns are missing from the dataset.")
# Out:
# <ipython-input-21-81ff658172a4>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Marital_Status', y='TotalNumPurchases', data=df, palette='Set1')

# %%
# The Relation between Total Number of Purchases and the Number of Children

import matplotlib.pyplot as plt
import seaborn as sns

# Check if the required columns exist
if all(col in df.columns for col in ['TotalNumPurchases', 'Children']):

    # Bar Plot (Average TotalNumPurchases per Number of Children)
    plt.figure(figsize=(10, 6))
    avg_purchases = df.groupby('Children')['TotalNumPurchases'].mean()
    sns.barplot(x=avg_purchases.index, y=avg_purchases.values, palette='Set3')
    plt.title('Average TotalNumPurchases by Number of Children', fontsize=14)
    plt.xlabel('Number of Children', fontsize=12)
    plt.ylabel('Average Total Number of Purchases', fontsize=12)
    plt.grid(alpha=0.4)
    plt.show()


else:
    print("One or more required columns are missing from the dataset.")
# Out:
# <ipython-input-27-27f1f69f4705>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_purchases.index, y=avg_purchases.values, palette='Set3')

# %%
# Visualising the Relationship between Income and Total Number of Purchases

from sklearn.linear_model import LinearRegression
import numpy as np

# Prepare data for regression
if all(col in df.columns for col in ['Income', 'TotalNumPurchases']):
    X = df[['Income']].dropna()  # Predictor
    y = df['TotalNumPurchases'].dropna()  # Target

    # Fit the model
    model = LinearRegression()
    model.fit(X, y)

    # Regression coefficients
    intercept = model.intercept_
    coefficient = model.coef_[0]

    print(f"Linear Regression Model: TotalNumPurchases = {intercept:.2f} + {coefficient:.2f} * Income")

    # Predict and visualize the regression line
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='Income', y='TotalNumPurchases', data=df, alpha=0.7, label="Actual Data")
    plt.plot(X, model.predict(X), color='red', label='Regression Line')
    plt.title('Income vs. TotalNumPurchases (with Regression Line)', fontsize=14)
    plt.xlabel('Income', fontsize=12)
    plt.ylabel('Total Number of Purchases', fontsize=12)
    plt.legend()
    plt.grid(alpha=0.4)
    plt.show()

else:
    print("One or more required columns are missing from the dataset.")
# Out:
# Linear Regression Model: TotalNumPurchases = 5.83 + 0.00 * Income

# %%
# The Relationship between Recency and Total Number of Purchases

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and contains 'Recency' and 'TotalNumPurchases' columns
plt.figure(figsize=(10, 6))

# Create a scatter plot with a regression line
sns.regplot(x='Recency', y='TotalNumPurchases', data=df, scatter_kws={'alpha': 0.6}, line_kws={'color': 'red', 'linewidth': 2})

# Customize the plot
plt.title('Relationship Between Recency and Total Number of Purchases', fontsize=14)
plt.xlabel('Recency (Days Since Last Purchase)', fontsize=12)
plt.ylabel('Total Number of Purchases', fontsize=12)
plt.grid(True, alpha=0.3)
plt.show()

# %%
# The Relationship between Customer Complaints and Total Number of Purchases

# Calculate mean number of purchases for customers with and without complaints
mean_purchases_by_complaint = df.groupby('Complain')['TotalNumPurchases'].mean()

# Create a bar plot
plt.figure(figsize=(8, 6))
mean_purchases_by_complaint.plot(kind='bar', color=['#66b3ff', '#ff9999'], alpha=0.8, edgecolor='black')

# Customize the plot
plt.title('Mean Total Number of Purchases by Complaint Status', fontsize=14)
plt.xlabel('Complaint Status (0 = No, 1 = Yes)', fontsize=12)
plt.ylabel('Average Total Number of Purchases', fontsize=12)
plt.xticks([0, 1], labels=['No Complaint', 'Complaint'], rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# The Relationship between Campaign Response and Total Number of Purchases

# Calculate mean number of purchases for each response group
mean_purchases = df.groupby('Response')['TotalNumPurchases'].mean()

# Create a bar plot
plt.figure(figsize=(8, 6))
mean_purchases.plot(kind='bar', color=['#66b3ff', '#ff9999'], alpha=0.8, edgecolor='black')

# Customize the plot
plt.title('Mean Total Number of Purchases by Response', fontsize=14)
plt.xlabel('Response (Yes/No)', fontsize=12)
plt.ylabel('Average Total Number of Purchases', fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
